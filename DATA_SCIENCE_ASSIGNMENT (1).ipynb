# %%
# !pip install pandas numpy nltk scikit-learn emoji

# %%
import pandas as pd
import numpy as np
import re
import emoji
import nltk

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
import pandas as pd
import numpy as np
import re
import emoji
import nltk

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
data_url = "https://raw.githubusercontent.com/dD2405/Twitter_Sentiment_Analysis/master/train.csv"

data = pd.read_csv(data_url)
data.head()
# Out:
#    id  label                                              tweet
# 0   1      0   @user when a father is dysfunctional and is s...
# 1   2      0  @user @user thanks for #lyft credit i can't us...
# 2   3      0                                bihday your majesty
# 3   4      0  #model   i love u take with u all the time in ...
# 4   5      0             factsguide: society now    #motivation

# %%
def preprocess_text(text):
    text = text.lower()
    text = re.sub(r"http\S+", "", text)   # remove links
    text = re.sub(r"@\w+", "", text)      # remove mentions
    text = re.sub(r"#", "", text)         # remove hashtag symbol
    text = emoji.replace_emoji(text, "") # remove emojis
    text = re.sub(r"[^a-z\s]", "", text)  # keep only letters
    text = re.sub(r"\s+", " ", text).strip()
    return text

data['filtered_text'] = data['tweet'].apply(preprocess_text)

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

stop_words = set(stopwords.words('english'))
ps = PorterStemmer()

def text_processing(text):
    words = word_tokenize(text)
    words = [w for w in words if w not in stop_words]
    words = [ps.stem(w) for w in words]
    return words

data['word_list'] = data['filtered_text'].apply(text_processing)

# %%
data['final_text'] = data['word_list'].apply(lambda x: " ".join(x))

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(max_features=4000)

X = tfidf.fit_transform(data['final_text'])
y = data['label']

print("Feature shape:", X.shape)
# Out:
# Feature shape: (31962, 4000)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

classifier = LogisticRegression(max_iter=300)
classifier.fit(X_train, y_train)

print("Model Accuracy:", classifier.score(X_test, y_test))
# Out:
# Model Accuracy: 0.9505693905643849

# %%
def live_tweet_stream(dataset):
    for row in dataset:
        yield row

stream_data = live_tweet_stream(data['filtered_text'])

# %%
for index, tweet in enumerate(stream_data):
    if index == 5:
        break
    processed = text_processing(tweet)
    print(processed)
# Out:
# ['father', 'dysfunct', 'selfish', 'drag', 'kid', 'dysfunct', 'run']
# ['thank', 'lyft', 'credit', 'cant', 'use', 'caus', 'dont', 'offer', 'wheelchair', 'van', 'pdx', 'disapoint', 'getthank']
# ['bihday', 'majesti']
# ['model', 'love', 'u', 'take', 'u', 'time', 'ur']
# ['factsguid', 'societi', 'motiv']

# %%
chunk_size = 800

for start in range(0, len(data), chunk_size):
    subset = data[start:start+chunk_size]
    print(f"Handling records {start} to {start+chunk_size}")
# Out:
# Handling records 0 to 800
# Handling records 800 to 1600
# Handling records 1600 to 2400
# Handling records 2400 to 3200
# Handling records 3200 to 4000
# Handling records 4000 to 4800
# Handling records 4800 to 5600
# Handling records 5600 to 6400
# Handling records 6400 to 7200
# Handling records 7200 to 8000
# Handling records 8000 to 8800
# Handling records 8800 to 9600
# Handling records 9600 to 10400
# Handling records 10400 to 11200
# Handling records 11200 to 12000
# Handling records 12000 to 12800
# Handling records 12800 to 13600
# Handling records 13600 to 14400
# Handling records 14400 to 15200
# Handling records 15200 to 16000
# Handling records 16000 to 16800
# Handling records 16800 to 17600
# Handling records 17600 to 18400
# Handling records 18400 to 19200
# Handling records 19200 to 20000
# Handling records 20000 to 20800
# Handling records 20800 to 21600
# Handling records 21600 to 22400
# Handling records 22400 to 23200
# Handling records 23200 to 24000
# ...
